# %%
#  Waste Classification using CNN (AICTE Edunet Internship)
# Week 1: Dataset Collection & Exploration

# Author: Vishal Chouhan
# Theme: Sustainability
# Dataset: Waste Classification Data (Kaggle)

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("techsash/waste-classification-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 427M/427M [00:02<00:00, 175MB/s]
# Extracting files...
# ✅ Path to dataset files: /root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1

# %%
import os

print("Inside 'dataset':", os.listdir(os.path.join(path, "dataset")))
print("Inside 'DATASET':", os.listdir(os.path.join(path, "DATASET")))
# Out:
# Inside 'dataset': ['DATASET']
# Inside 'DATASET': ['TRAIN', 'TEST']

# %%
import os

# this is actual dataset path
data_dir = os.path.join(path, "dataset", "DATASET", "TRAIN")

print(" Final training data path:", data_dir)
print(" Subfolders (categories):", os.listdir(data_dir))
# Out:
# ✅ Final training data path: /root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1/dataset/DATASET/TRAIN
# 📂 Subfolders (categories): ['O', 'R']

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    train_dir,
    target_size=(128,128),
    batch_size=32,
    subset='training'
)

val_data = datagen.flow_from_directory(
    train_dir,
    target_size=(128,128),
    batch_size=32,
    subset='validation'
)
# Out:
# Found 18052 images belonging to 2 classes.
# Found 4512 images belonging to 2 classes.

# %%
# sample images from data
x, y = next(train_data)

plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x[i])
    plt.axis('off')
plt.show()

# %%
print("Total training images:", train_data.samples)
print("Total validation images:", val_data.samples)
print("Classes:", train_data.class_indices)
# Out:
# Total training images: 18052
# Total validation images: 4512
# Classes: {'O': 0, 'R': 1}

# %%
#  Week 1 Summary

#✅ Downloaded dataset from Kaggle (Waste Classification Data)
#✅ Verified folder structure (TRAIN & TEST)
#✅ Loaded dataset using Keras ImageDataGenerator
#✅ Ready for model building in Week 2
